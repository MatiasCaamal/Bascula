# %% [markdown]
# <a href="https://colab.research.google.com/github/MatiasCaamal/Bascula/blob/main/P4_Modelo_RBPi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cargamos nuestro drive en el notebook de trabajo
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Residencia')

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Cargar modelo entrenado
model = YOLO("runs/classify/final2/weights/best.pt")

# Exportar a ONNX
model.export(format='onnx', opset=17)
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv8n-cls summary (fused): 30 layers, 1,447,690 parameters, 0 gradients, 3.3 GFLOPs
#
# PyTorch: starting from 'runs/classify/final2/weights/best.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 10) (2.8 MB)
#
# ONNX: starting export with onnx 1.19.1 opset 17...
# ONNX: slimming with onnxslim 0.1.78...
# ONNX: export success ✅ 0.4s, saved as 'runs/classify/final2/weights/best.onnx' (5.6 MB)
#
# Export complete (0.5s)
# Results saved to /content/drive/MyDrive/Residencia/runs/classify/final2/weights
# Predict:         yolo predict task=classify model=runs/classify/final2/weights/best.onnx imgsz=224
# Validate:        yolo val task=classify model=runs/classify/final2/weights/best.onnx imgsz=224 data=/kaggle/working/Frutas_cls2
# Visualize:       https://netron.app
# 'runs/classify/final2/weights/best.onnx'

# %%
from google.colab import files
files.download('runs/classify/final2/weights/best.onnx')
